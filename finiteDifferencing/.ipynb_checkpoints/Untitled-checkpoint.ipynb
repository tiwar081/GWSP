# %%
import numpy as np
import scipy as sci
import matplotlib.pyplot as plt

# %%
x = np.linspace(-10, 10, 1000)
y = x**2
dydx = 2*x

# %%
plt.plot(x, y, label='y=x^2')
plt.plot(x, dydx, label='y=2x')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.plot()
# Out:
# []

# %%
deltax = np.array(1, 0.5, 0.1, 0.05, 1e-3)

def finite_differencing(y, dx):
    n = len(y)
    derivative = np.zeros_like(y)

    for i in range(1, n-1):
        derivative[i] = (y[i+1] - y[i-1]) / (2 * y)

    derivative[0] = (arr[1] - arr[0]) / delta_x

    # Backward difference at the last point
    derivative[-1] = (arr[-1] - arr[-2]) / delta_x

    return derivative
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 deltax = np.array(1, 0.5, 0.1, 0.05, 1e-3)
#       3 def finite_differencing(x, dx):
#       4     dydx_fd = np.zeros(len(x))
#
# TypeError: array() takes from 1 to 2 positional arguments but 5 were given
